# %%
# !python "/content/drive/Othercomputers/My Computer/Nguyen Tri/Code/Statisanalyss/Code/train.py"

# %% [markdown]
# The error message `FileNotFoundError: [Errno 2] No such file or directory: 'C:\Nguyen Tri\Code\Statisanalyss\all_training_data.csv/content/drive/Othercomputers/My Computer/Nguyen Tri/Code/Statisanalyss/All_Races_Aggregated.csv'` indicates that the `DATA_PATH` variable in your `train.py` script is constructed incorrectly. It appears to be concatenating a Windows-style path (`C:\...`) with the correct Colab path (`/content/drive/...`).
#
# You need to modify your `train.py` file to ensure `DATA_PATH` points directly to the correct file in your Google Drive, which should be something like `/content/drive/Othercomputers/My Computer/Nguyen Tri/Code/Statisanalyss/All_Races_Aggregated.csv` or a relative path from the current working directory.

# %% [markdown]
# To help you verify the correct file name and location, let's list the contents of the current directory:

# %%
# !ls -R

# %% [markdown]
# Please examine the output above to find the exact path to `All_Races_Aggregated.csv` and then update the `DATA_PATH` variable in your `train.py` script accordingly. If the file is in the parent directory of `Code`, you might use `../All_Races_Aggregated.csv` as the relative path, or the full absolute path.
